# %% [markdown]
# #
# Factor_Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
var=sns.load_dataset("tips").head(50)

# %%
sns.catplot(x="total_bill",y="tip",data=var,kind="bar")
plt.show()

# %%
import seaborn as sns
print(sns.__version__)
# Out:
# 0.13.2
